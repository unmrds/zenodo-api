# %% [markdown]
# This notebook is intended for testing Zenodo API access and submission files.
#
# Zenodo API documentation: https://developers.zenodo.org/#rest-api
#
# ## Run the following code block once before executing any of the subsequent code blocks
#
# It loads the required python libraries, defines the endpoints for the Zenodo API and the corresponding sandbox, and prompts the user for their access tokens for both the production and sandbox systems.

# %%
# import libraries
import requests     # for interacting with the sandbox and production APIs 
import getpass      # for prompting for API Access Key
import json         # for manipulating JSON string

# define API endpoint prefixes
sandbox = "https://sandbox.zenodo.org/api/"
production = "https://zenodo.org/api/"

# get the user's API access tokens
# the sandbox is a separate clone of the Zenodo platform and a separate account and associated
# access tokens must be created in the sandbox to use the sandbox API
productionAccessToken=getpass.getpass(prompt='Production access token: ')
sandboxAccessToken=getpass.getpass(prompt='Sandbox access token: ')
# Out:
# Production access token: ········
# Sandbox access token: ········

# %% [markdown]
# ## Retrieve deposits associated with the provided access token in Zenodo's production and sandbox systems through authenticated get requests

# %%
# compose the request
r = requests.get(production + "deposit/depositions",
                params={'access_token':productionAccessToken})
print(json.dumps(r.json(), indent=2))

r = requests.get(sandbox + "deposit/depositions",
                params={'access_token':sandboxAccessToken})
print(json.dumps(r.json(), indent=2))
# Out:
# [
#   {
#     "conceptdoi": "10.5281/zenodo.6949636",
#     "conceptrecid": "6949636",
#     "created": "2022-08-01T16:59:03.099374",
#     "doi": "10.5281/zenodo.6949637",
#     "doi_url": "https://doi.org/10.5281/zenodo.6949637",
#     "files": [
#       {
#         "checksum": "9ec19eeb31d12441266e59bfe6e1fc97",
#         "filename": "unmrds/cc-python-1.0.zip",
#         "filesize": 1072597,
#         "id": "51b74e05-058c-45bb-bc87-68e8ef38b3c7",
#         "links": {
#           "download": "https://zenodo.org/api/files/63f9a73f-ec3f-40c6-81e6-2a01995c208c/unmrds/cc-python-1.0.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/6949637/files/51b74e05-058c-45bb-bc87-68e8ef38b3c7"
#         }
#       }
#     ],
#     "id": 6949637,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.6949637.svg",
#       "bucket": "https://zenodo.org/api/files/ab831ac7-1317-44ad-a61c-54912c1f1fd6",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.6949636.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.6949636",
#       "discard": "https://zenodo.org/api/deposit/depositions/6949637/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.6949637",
#       "edit": "https://zenodo.org/api/deposit/depositions/6949637/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/6949637/files",
#       "html": "https://zenodo.org/deposit/6949637",
#       "latest": "https://zenodo.org/api/records/6949637",
#       "latest_html": "https://zenodo.org/record/6949637",
#       "publish": "https://zenodo.org/api/deposit/depositions/6949637/actions/publish",
#       "record": "https://zenodo.org/api/records/6949637",
#       "record_html": "https://zenodo.org/record/6949637",
#       "self": "https://zenodo.org/api/deposit/depositions/6949637"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         },
#         {
#           "name": "datarescue-albquerque"
#         },
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Jonathan Wheeler"
#         }
#       ],
#       "description": "<p>This is the first release of the workshop content - representing the state of the workshop in Spring 2022</p>",
#       "doi": "10.5281/zenodo.6949637",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.6949637",
#         "recid": 6949637
#       },
#       "publication_date": "2022-08-01",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/unmrds/cc-python/tree/1.0",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "unmrds/cc-python: Coffee & Code Python workshop - Initial release Spring 2022 version",
#       "upload_type": "software",
#       "version": "1.0"
#     },
#     "modified": "2022-08-01T16:59:05.604887",
#     "owner": 10428,
#     "record_id": 6949637,
#     "state": "done",
#     "submitted": true,
#     "title": "unmrds/cc-python: Coffee & Code Python workshop - Initial release Spring 2022 version"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.842038",
#     "conceptrecid": "842038",
#     "created": "2019-05-07T22:10:05.835545",
#     "doi": "10.5281/zenodo.2673002",
#     "doi_url": "https://doi.org/10.5281/zenodo.2673002",
#     "files": [
#       {
#         "checksum": "2de86525f6465c861b39ee9c3b9168c1",
#         "filename": "karlbenedict/OILS515-2017-Fall-Final.zip",
#         "filesize": 92876651,
#         "id": "7c8b73c7-4267-4c5a-a65d-a604185c596e",
#         "links": {
#           "download": "https://zenodo.org/api/files/be38b3e7-6c1a-468b-8951-e69a6ce0c6d4/karlbenedict/OILS515-2017-Fall-Final.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/2673002/files/7c8b73c7-4267-4c5a-a65d-a604185c596e"
#         }
#       }
#     ],
#     "id": 2673002,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.2673002.svg",
#       "bucket": "https://zenodo.org/api/files/3789d27d-5947-428c-8785-4f807fcf7945",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.842038.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.842038",
#       "discard": "https://zenodo.org/api/deposit/depositions/2673002/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.2673002",
#       "edit": "https://zenodo.org/api/deposit/depositions/2673002/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/2673002/files",
#       "html": "https://zenodo.org/deposit/2673002",
#       "latest": "https://zenodo.org/api/records/2673002",
#       "latest_html": "https://zenodo.org/record/2673002",
#       "publish": "https://zenodo.org/api/deposit/depositions/2673002/actions/publish",
#       "record": "https://zenodo.org/api/records/2673002",
#       "record_html": "https://zenodo.org/record/2673002",
#       "self": "https://zenodo.org/api/deposit/depositions/2673002"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         }
#       ],
#       "description": "<p>This is the final state of the repository as it existed at the end of the Fall 2017 Fall term.</p>",
#       "doi": "10.5281/zenodo.2673002",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.2673002",
#         "recid": 2673002
#       },
#       "publication_date": "2019-05-07",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/karlbenedict/OILS515/tree/2017-Fall-Final",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "karlbenedict/OILS515: Final version of OILS 515 materials at the end of Fall 2017",
#       "upload_type": "software",
#       "version": "2017-Fall-Final"
#     },
#     "modified": "2021-06-28T14:38:36.388859",
#     "owner": 10428,
#     "record_id": 2673002,
#     "state": "inprogress",
#     "submitted": true,
#     "title": "karlbenedict/OILS515: Final version of OILS 515 materials at the end of Fall 2017"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.4713635",
#     "conceptrecid": "4713635",
#     "created": "2021-04-23T04:29:11.064112",
#     "doi": "10.5281/zenodo.4713636",
#     "doi_url": "https://doi.org/10.5281/zenodo.4713636",
#     "files": [
#       {
#         "checksum": "c3e6ae77a7d4611b8297fd3e28ce7435",
#         "filename": "unmrds/cc-reproducibility-communication-v2021-04-23.zip",
#         "filesize": 17061875,
#         "id": "50c69b1a-2f4b-4e0c-90f0-a2d954e5e27f",
#         "links": {
#           "download": "https://zenodo.org/api/files/08aadd29-18de-4189-879d-181994a0d6c4/unmrds/cc-reproducibility-communication-v2021-04-23.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/4713636/files/50c69b1a-2f4b-4e0c-90f0-a2d954e5e27f"
#         }
#       }
#     ],
#     "id": 4713636,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.4713636.svg",
#       "bucket": "https://zenodo.org/api/files/d87a8fef-66d3-4158-b1ce-207de6df34d5",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.4713635.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.4713635",
#       "discard": "https://zenodo.org/api/deposit/depositions/4713636/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.4713636",
#       "edit": "https://zenodo.org/api/deposit/depositions/4713636/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/4713636/files",
#       "html": "https://zenodo.org/deposit/4713636",
#       "latest": "https://zenodo.org/api/records/4713636",
#       "latest_html": "https://zenodo.org/record/4713636",
#       "publish": "https://zenodo.org/api/deposit/depositions/4713636/actions/publish",
#       "record": "https://zenodo.org/api/records/4713636",
#       "record_html": "https://zenodo.org/record/4713636",
#       "self": "https://zenodo.org/api/deposit/depositions/4713636"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         },
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Jonathan Wheeler"
#         }
#       ],
#       "description": "This workshop provides an introduction to reproducibility and communication of research using notebooks based on RStudio and Jupyter Notebooks",
#       "doi": "10.5281/zenodo.4713636",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.4713636",
#         "recid": 4713636
#       },
#       "publication_date": "2021-04-23",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/unmrds/cc-reproducibility-communication/tree/v2021-04-23",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "unmrds/cc-reproducibility-communication: Release for the 2021-04-23 Coffee & Code workshop",
#       "upload_type": "software",
#       "version": "v2021-04-23"
#     },
#     "modified": "2021-04-23T04:29:31.019665",
#     "owner": 10428,
#     "record_id": 4713636,
#     "state": "done",
#     "submitted": true,
#     "title": "unmrds/cc-reproducibility-communication: Release for the 2021-04-23 Coffee & Code workshop"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.4695129",
#     "conceptrecid": "4695129",
#     "created": "2021-04-15T19:39:54.225536",
#     "doi": "10.5281/zenodo.4695130",
#     "doi_url": "https://doi.org/10.5281/zenodo.4695130",
#     "files": [
#       {
#         "checksum": "713545b978e47ac142527d75bbb2ed4a",
#         "filename": "unmrds/cc-containers-1.0.zip",
#         "filesize": 2891486,
#         "id": "f30c3702-cd3c-418c-ba64-f7fa67b327d0",
#         "links": {
#           "download": "https://zenodo.org/api/files/a2b5eeed-462d-451f-9c76-287bb28177f9/unmrds/cc-containers-1.0.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/4695130/files/f30c3702-cd3c-418c-ba64-f7fa67b327d0"
#         }
#       }
#     ],
#     "id": 4695130,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.4695130.svg",
#       "bucket": "https://zenodo.org/api/files/6498348d-0788-4816-a673-4d990d48529a",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.4695129.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.4695129",
#       "discard": "https://zenodo.org/api/deposit/depositions/4695130/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.4695130",
#       "edit": "https://zenodo.org/api/deposit/depositions/4695130/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/4695130/files",
#       "html": "https://zenodo.org/deposit/4695130",
#       "latest": "https://zenodo.org/api/records/4695130",
#       "latest_html": "https://zenodo.org/record/4695130",
#       "publish": "https://zenodo.org/api/deposit/depositions/4695130/actions/publish",
#       "record": "https://zenodo.org/api/records/4695130",
#       "record_html": "https://zenodo.org/record/4695130",
#       "self": "https://zenodo.org/api/deposit/depositions/4695130"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         },
#         {
#           "name": "datarescue-albquerque"
#         },
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Jonathan Wheeler"
#         }
#       ],
#       "description": "Coffee &amp; Code - Containers with Docker",
#       "doi": "10.5281/zenodo.4695130",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.4695130",
#         "recid": 4695130
#       },
#       "publication_date": "2021-04-15",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/unmrds/cc-containers/tree/1.0",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "unmrds/cc-containers: Initial release of the Coffee & Code Containers lesson",
#       "upload_type": "software",
#       "version": "1.0"
#     },
#     "modified": "2021-04-15T19:39:57.693334",
#     "owner": 10428,
#     "record_id": 4695130,
#     "state": "done",
#     "submitted": true,
#     "title": "unmrds/cc-containers: Initial release of the Coffee & Code Containers lesson"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.4413268",
#     "conceptrecid": "4413268",
#     "created": "2021-01-03T18:18:55.237967",
#     "doi": "10.5281/zenodo.4413269",
#     "doi_url": "https://doi.org/10.5281/zenodo.4413269",
#     "files": [
#       {
#         "checksum": "f4435688d56f28e8989d7fbd694b0675",
#         "filename": "unmrds/impact-survey-v1.0.zip",
#         "filesize": 111963,
#         "id": "bb65000a-cc0f-40e9-a91c-f16ba9d549d7",
#         "links": {
#           "download": "https://zenodo.org/api/files/0c7ee326-734e-40c0-8c11-f846685394f5/unmrds/impact-survey-v1.0.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/4413269/files/bb65000a-cc0f-40e9-a91c-f16ba9d549d7"
#         }
#       }
#     ],
#     "id": 4413269,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.4413269.svg",
#       "bucket": "https://zenodo.org/api/files/7e0d98a1-8bd8-4192-93ac-842c71f9e0da",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.4413268.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.4413268",
#       "discard": "https://zenodo.org/api/deposit/depositions/4413269/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.4413269",
#       "edit": "https://zenodo.org/api/deposit/depositions/4413269/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/4413269/files",
#       "html": "https://zenodo.org/deposit/4413269",
#       "latest": "https://zenodo.org/api/records/4413269",
#       "latest_html": "https://zenodo.org/record/4413269",
#       "publish": "https://zenodo.org/api/deposit/depositions/4413269/actions/publish",
#       "record": "https://zenodo.org/api/records/4413269",
#       "record_html": "https://zenodo.org/record/4413269",
#       "self": "https://zenodo.org/api/deposit/depositions/4413269"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         }
#       ],
#       "description": "<p>This is the initial release of the RDS impact survey instrument including a static PDF version of the survey, and a link to the interactive version hosted in SurveyMonkey.</p>",
#       "doi": "10.5281/zenodo.4413269",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.4413269",
#         "recid": 4413269
#       },
#       "publication_date": "2021-01-03",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/unmrds/impact-survey/tree/v1.0",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "unmrds/impact-survey: RDS Impact Survey - Initial release",
#       "upload_type": "software",
#       "version": "v1.0"
#     },
#     "modified": "2021-01-03T18:19:00.424009",
#     "owner": 10428,
#     "record_id": 4413269,
#     "state": "done",
#     "submitted": true,
#     "title": "unmrds/impact-survey: RDS Impact Survey - Initial release"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.4395194",
#     "conceptrecid": "4395194",
#     "created": "2020-12-27T22:19:10.893151",
#     "doi": "10.5281/zenodo.4395195",
#     "doi_url": "https://doi.org/10.5281/zenodo.4395195",
#     "files": [
#       {
#         "checksum": "a45880897087f48b48852038d643741f",
#         "filename": "unmrds/cc-content-platform-V1.0.zip",
#         "filesize": 2580598,
#         "id": "7a0980a4-4969-41a3-83d9-ee11bcc918a2",
#         "links": {
#           "download": "https://zenodo.org/api/files/889785ae-081c-4f19-9afb-22fdcb04adea/unmrds/cc-content-platform-V1.0.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/4395195/files/7a0980a4-4969-41a3-83d9-ee11bcc918a2"
#         }
#       }
#     ],
#     "id": 4395195,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.4395195.svg",
#       "bucket": "https://zenodo.org/api/files/6b8afd57-9fcd-4210-a121-ee4c879c4c68",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.4395194.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.4395194",
#       "discard": "https://zenodo.org/api/deposit/depositions/4395195/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.4395195",
#       "edit": "https://zenodo.org/api/deposit/depositions/4395195/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/4395195/files",
#       "html": "https://zenodo.org/deposit/4395195",
#       "latest": "https://zenodo.org/api/records/4395195",
#       "latest_html": "https://zenodo.org/record/4395195",
#       "publish": "https://zenodo.org/api/deposit/depositions/4395195/actions/publish",
#       "record": "https://zenodo.org/api/records/4395195",
#       "record_html": "https://zenodo.org/record/4395195",
#       "self": "https://zenodo.org/api/deposit/depositions/4395195"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         },
#         {
#           "name": "datarescue-albquerque"
#         }
#       ],
#       "description": "<p>This is the first release of the platform that has been under development since 2018.</p>",
#       "doi": "10.5281/zenodo.4395195",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.4395195",
#         "recid": 4395195
#       },
#       "publication_date": "2020-12-27",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/unmrds/cc-content-platform/tree/V1.0",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "unmrds/cc-content-platform: Initial release of the Coffee & Code teaching and learning platform",
#       "upload_type": "software",
#       "version": "V1.0"
#     },
#     "modified": "2020-12-27T22:19:14.099567",
#     "owner": 10428,
#     "record_id": 4395195,
#     "state": "done",
#     "submitted": true,
#     "title": "unmrds/cc-content-platform: Initial release of the Coffee & Code teaching and learning platform"
#   },
#   {
#     "conceptdoi": "10.5281/zenodo.593400",
#     "conceptrecid": "593400",
#     "created": "2018-01-14T04:00:35.741362",
#     "doi": "10.5281/zenodo.1146906",
#     "doi_url": "https://doi.org/10.5281/zenodo.1146906",
#     "files": [
#       {
#         "checksum": "df771c9e28a44d07a432750a8dbbf1b7",
#         "filename": "karlbenedict/GEOG485-585-v2017.final.zip",
#         "filesize": 188869216,
#         "id": "e9de9583-2b17-449c-a629-1fa12e356bc5",
#         "links": {
#           "download": "https://zenodo.org/api/files/9c7471bc-090e-4318-9706-9037119d48cb/karlbenedict/GEOG485-585-v2017.final.zip",
#           "self": "https://zenodo.org/api/deposit/depositions/1146906/files/e9de9583-2b17-449c-a629-1fa12e356bc5"
#         }
#       }
#     ],
#     "id": 1146906,
#     "links": {
#       "badge": "https://zenodo.org/badge/doi/10.5281/zenodo.1146906.svg",
#       "bucket": "https://zenodo.org/api/files/77440367-11f5-4d34-b528-960754140a19",
#       "conceptbadge": "https://zenodo.org/badge/doi/10.5281/zenodo.593400.svg",
#       "conceptdoi": "https://doi.org/10.5281/zenodo.593400",
#       "discard": "https://zenodo.org/api/deposit/depositions/1146906/actions/discard",
#       "doi": "https://doi.org/10.5281/zenodo.1146906",
#       "edit": "https://zenodo.org/api/deposit/depositions/1146906/actions/edit",
#       "files": "https://zenodo.org/api/deposit/depositions/1146906/files",
#       "html": "https://zenodo.org/deposit/1146906",
#       "latest": "https://zenodo.org/api/records/1146906",
#       "latest_html": "https://zenodo.org/record/1146906",
#       "publish": "https://zenodo.org/api/deposit/depositions/1146906/actions/publish",
#       "record": "https://zenodo.org/api/records/1146906",
#       "record_html": "https://zenodo.org/record/1146906",
#       "self": "https://zenodo.org/api/deposit/depositions/1146906"
#     },
#     "metadata": {
#       "access_right": "open",
#       "creators": [
#         {
#           "affiliation": "University of New Mexico",
#           "name": "Karl Benedict"
#         }
#       ],
#       "description": "<p>This is a snapshot of the full collection of source markdown for course content; HTML, CSS and javascript for class examples; and generated PDF, and HTML documents derived from the markdown source files. This release represents the final collection of files at the completion of the Spring 2017 term.</p>",
#       "doi": "10.5281/zenodo.1146906",
#       "license": "other-open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.1146906",
#         "recid": 1146906
#       },
#       "publication_date": "2018-01-14",
#       "related_identifiers": [
#         {
#           "identifier": "https://github.com/karlbenedict/GEOG485-585/tree/v2017.final",
#           "relation": "isSupplementTo",
#           "scheme": "url"
#         }
#       ],
#       "title": "karlbenedict/GEOG485-585: Final release of Spring 2017 course materials",
#       "upload_type": "software",
#       "version": "v2017.final"
#     },
#     "modified": "2018-01-14T04:02:03.135814",
#     "owner": 10428,
#     "record_id": 1146906,
#     "state": "done",
#     "submitted": true,
#     "title": "karlbenedict/GEOG485-585: Final release of Spring 2017 course materials"
#   }
# ]
# [
#   {
#     "conceptrecid": "1096442",
#     "created": "2022-08-25T19:41:17.161763",
#     "id": 1096443,
#     "links": {
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/1096443/actions/discard",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/1096443/actions/edit",
#       "files": "https://sandbox.zenodo.org/api/deposit/depositions/1096443/files",
#       "html": "https://sandbox.zenodo.org/deposit/1096443",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/1096443/actions/publish",
#       "self": "https://sandbox.zenodo.org/api/deposit/depositions/1096443"
#     },
#     "metadata": {
#       "prereserve_doi": {
#         "doi": "10.5072/zenodo.1096443",
#         "recid": 1096443
#       }
#     },
#     "modified": "2022-08-25T19:41:17.161781",
#     "owner": 10428,
#     "record_id": 1096443,
#     "state": "unsubmitted",
#     "submitted": false,
#     "title": ""
#   },
#   {
#     "conceptrecid": "1096440",
#     "created": "2022-08-25T19:31:24.124321",
#     "id": 1096441,
#     "links": {
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/1096441/actions/discard",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/1096441/actions/edit",
#       "files": "https://sandbox.zenodo.org/api/deposit/depositions/1096441/files",
#       "html": "https://sandbox.zenodo.org/deposit/1096441",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/1096441/actions/publish",
#       "self": "https://sandbox.zenodo.org/api/deposit/depositions/1096441"
#     },
#     "metadata": {
#       "prereserve_doi": {
#         "doi": "10.5072/zenodo.1096441",
#         "recid": 1096441
#       }
#     },
#     "modified": "2022-08-25T19:31:24.124339",
#     "owner": 10428,
#     "record_id": 1096441,
#     "state": "unsubmitted",
#     "submitted": false,
#     "title": ""
#   }
# ]

# %% [markdown]
# ## Submit a dataset and associated metadata to the Zenodo Sandbox
#
# This can be used to troubleshoot/test files and associated metadata prior to submission. Particularly helpful for troubleshooting .zenodo.json metadata files prior to generating a Github release that might result in a Zenodo metadata error.

# %%
# Based upon Zenodo Quick Start sample code - https://developers.zenodo.org/#quickstart-upload
# customize the following variables to reference the desired data file and associated metadata

filename = "testdata.txt"
metaFilename = "testmetadata.json"
datapath = "./%s" % filename
metadatapath = "./%s" % metaFilename

# set the reusable params and headers for reuse in multiple API calls
params = {'access_token':sandboxAccessToken}
headers = {"Content-Type": "application/json"}

##################################################################
# Create an empty upload into which data and metadata can be added 
r = requests.post(sandbox + 'deposit/depositions',
                 params = params,
                 json = {},
                 headers = headers)
# create some variables from the creation response for future use
bucketURL = r.json()["links"]["bucket"]
depositionID = r.json()["id"]

print('POST response:')
print(json.dumps(r.json(), indent=2))

#############################################
# Upload a file into the created upload space
with open(datapath, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucketURL, filename),
        data = fp,
        params = params
    )
print("File upload PUT response")
print(json.dumps(r.json(), indent=2))

###########################################
# Upload a metadata file for the deposition
with open(metadatapath, "rt") as fp:
    rawMetadata = json.load(fp)
    submitMetadata = {'metadata':rawMetadata}
    print("Metadata to be submitted: ")
    print(json.dumps(submitMetadata, indent=2))
    r = requests.put(
        sandbox + "deposit/depositions/" + str(depositionID),
        params = params,
        data = json.dumps(submitMetadata),
        headers = headers
    )
print("Metadata upload PUT response")
print(json.dumps(r.json(), indent=2))
# Out:
# POST response:
# {
#   "conceptrecid": "1096461",
#   "created": "2022-08-25T20:31:49.967608+00:00",
#   "files": [],
#   "id": 1096462,
#   "links": {
#     "bucket": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b",
#     "discard": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/discard",
#     "edit": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/edit",
#     "files": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/files",
#     "html": "https://sandbox.zenodo.org/deposit/1096462",
#     "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/1096462",
#     "latest_draft_html": "https://sandbox.zenodo.org/deposit/1096462",
#     "publish": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/publish",
#     "self": "https://sandbox.zenodo.org/api/deposit/depositions/1096462"
#   },
#   "metadata": {
#     "prereserve_doi": {
#       "doi": "10.5072/zenodo.1096462",
#       "recid": 1096462
#     }
#   },
#   "modified": "2022-08-25T20:31:49.967617+00:00",
#   "owner": 10428,
#   "record_id": 1096462,
#   "state": "unsubmitted",
#   "submitted": false,
#   "title": ""
# }
# File upload PUT response
# {
#   "mimetype": "text/plain",
#   "updated": "2022-08-25T20:31:51.644322+00:00",
#   "links": {
#     "self": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b/testdata.txt",
#     "version": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b/testdata.txt?versionId=9a319a43-4aa8-408b-8d77-829748c2e849",
#     "uploads": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b/testdata.txt?uploads"
#   },
#   "is_head": true,
#   "created": "2022-08-25T20:31:51.636341+00:00",
#   "checksum": "md5:647a786a3d2ab5bfb639b61eeaa3d8e8",
#   "version_id": "9a319a43-4aa8-408b-8d77-829748c2e849",
#   "delete_marker": false,
#   "key": "testdata.txt",
#   "size": 56
# }
# {
#   "metadata": {
#     "version": "0.1.0-2022-07ESIPDemo",
#     "title": "User interface code for the Data Management Training Clearinghouse",
#     "description": "This is the collection of VUE 3 code developed in support of the <a href='https://www.dmtc-prod.org/home'>user interface</a> for the enhanced Data Management Training Clearinghouse from 2018-2022. This user interface is designed as a single-page web application and is dependent upon the server-side <a href='https://www.dmtc-prod.org/api'>application programming interface (API)</a> developed in parallel with the user interface. Development of the user interface and underlying service platform has been supported by the Institute of Museum and Library Services (https://ror.org/030prv062, Award Number LG-70-18-0092-18), the Science Gateways Community Institute, and the Earth Science Information Partners (https://ror.org/03q5xa910).",
#     "keywords": [
#       "Data Management Training",
#       "Software",
#       "User Interface",
#       "Vue 3",
#       "Clearinghouse"
#     ],
#     "creators": [
#       {
#         "name": "Benedict, Karl",
#         "affiliation": "University of New Mexico",
#         "orcid": "0000-0002-9109-2072"
#       },
#       {
#         "name": "Wong, Mona",
#         "affiliation": "San Diego Supercomputer Center"
#       },
#       {
#         "name": "Hoebelheinrich, Nancy",
#         "affiliation": "Knowledge Motifs, LLC",
#         "orcid": "0000-0002-6797-7903"
#       },
#       {
#         "name": "Barrett, Hays",
#         "affiliation": "University of New Mexico"
#       }
#     ],
#     "upload_type": "software",
#     "access_right": "open",
#     "license": "Apache-2.0",
#     "notes": "<p>Required components to build and test the web application on a local development system include:</p> <ul>     <li>Docker - to run a local Apache container that can serve the devel, testing, or master (production) branches of the repository</li>     <li>Node.js - to provide the local toolchain for developing and building the app using NPM and the Vue CLI</li>     <li>NPM (typically installed with Node.js) - for installing the module dependencies and building the production app code</li>     <li>Vue CLI - for bootstrapping the development of a new Vue app if needed</li> </ul> <p>The module dependencies for the application are not included in the repository due to size requirements and should be installed in the local build/development environment by changing into the ui directory, and executing the npm install command.</p>  <p>For interactive development and previewing of updates, the npm run serve command can be run from the ui directory. Saved changes to the application source code will be reflected in the locally running instance of the application interface at localhost:8080 in a web browser.</p>  <p>Following successful installation of the application dependencies the production code for the application can be generated by changing into the ui directory and executing the npm run build command.</p>  <p>The three provided shell scripts:</p>  <p><code>rebuild-restart-devel.sh</code>, <code>rebuild-restart-testing.sh</code>, and <code>rebuild-restart-production.sh</code> automate the process of checking out the appropriate repository branch, stopping (if running) the corresponding apache web server (devel, testing, or production), removing and rebuilding the corresponding Docker image, and restarting the corresponding Docker container. When these commands are executed the running containers and associated user interface can be accessed at:</p> <ul>     <li>devel - localhost:8082</li>     <li>testing - localhost:8081</li>     <li>production - localhost:80</li> </ul>",
#     "contributors": [
#       {
#         "name": "Earth Science Information Partners",
#         "type": "Sponsor"
#       },
#       {
#         "name": "Earth Science Information Partners",
#         "type": "HostingInstitution"
#       },
#       {
#         "name": "Institute of Museum and Library Services (IMLS)",
#         "type": "Sponsor"
#       },
#       {
#         "name": "Science Gateway Community Institute",
#         "type": "Sponsor"
#       }
#     ]
#   }
# }
# Metadata upload PUT response
# {
#   "conceptrecid": "1096461",
#   "created": "2022-08-25T20:31:49.967608+00:00",
#   "doi": "",
#   "doi_url": "https://doi.org/",
#   "files": [
#     {
#       "checksum": "647a786a3d2ab5bfb639b61eeaa3d8e8",
#       "filename": "testdata.txt",
#       "filesize": 56,
#       "id": "42929876-5425-48d3-b6a3-7175fd2188f5",
#       "links": {
#         "download": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b/testdata.txt",
#         "self": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/files/42929876-5425-48d3-b6a3-7175fd2188f5"
#       }
#     }
#   ],
#   "id": 1096462,
#   "links": {
#     "bucket": "https://sandbox.zenodo.org/api/files/bef25ae1-cb05-41df-a825-0fd956729a9b",
#     "discard": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/discard",
#     "edit": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/edit",
#     "files": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/files",
#     "html": "https://sandbox.zenodo.org/deposit/1096462",
#     "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/1096462",
#     "latest_draft_html": "https://sandbox.zenodo.org/deposit/1096462",
#     "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/newversion",
#     "publish": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/publish",
#     "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/1096462/actions/registerconceptdoi",
#     "self": "https://sandbox.zenodo.org/api/deposit/depositions/1096462"
#   },
#   "metadata": {
#     "access_right": "open",
#     "contributors": [
#       {
#         "name": "Earth Science Information Partners",
#         "type": "Sponsor"
#       },
#       {
#         "name": "Earth Science Information Partners",
#         "type": "HostingInstitution"
#       },
#       {
#         "name": "Institute of Museum and Library Services (IMLS)",
#         "type": "Sponsor"
#       },
#       {
#         "name": "Science Gateway Community Institute",
#         "type": "Sponsor"
#       }
#     ],
#     "creators": [
#       {
#         "affiliation": "University of New Mexico",
#         "name": "Benedict, Karl",
#         "orcid": "0000-0002-9109-2072"
#       },
#       {
#         "affiliation": "San Diego Supercomputer Center",
#         "name": "Wong, Mona"
#       },
#       {
#         "affiliation": "Knowledge Motifs, LLC",
#         "name": "Hoebelheinrich, Nancy",
#         "orcid": "0000-0002-6797-7903"
#       },
#       {
#         "affiliation": "University of New Mexico",
#         "name": "Barrett, Hays"
#       }
#     ],
#     "description": "This is the collection of VUE 3 code developed in support of the <a href=\"https://www.dmtc-prod.org/home\">user interface</a> for the enhanced Data Management Training Clearinghouse from 2018-2022. This user interface is designed as a single-page web application and is dependent upon the server-side <a href=\"https://www.dmtc-prod.org/api\">application programming interface (API)</a> developed in parallel with the user interface. Development of the user interface and underlying service platform has been supported by the Institute of Museum and Library Services (https://ror.org/030prv062, Award Number LG-70-18-0092-18), the Science Gateways Community Institute, and the Earth Science Information Partners (https://ror.org/03q5xa910).",
#     "doi": "",
#     "keywords": [
#       "Data Management Training",
#       "Software",
#       "User Interface",
#       "Vue 3",
#       "Clearinghouse"
#     ],
#     "license": "Apache-2.0",
#     "notes": "<p>Required components to build and test the web application on a local development system include:</p> <ul>     <li>Docker - to run a local Apache container that can serve the devel, testing, or master (production) branches of the repository</li>     <li>Node.js - to provide the local toolchain for developing and building the app using NPM and the Vue CLI</li>     <li>NPM (typically installed with Node.js) - for installing the module dependencies and building the production app code</li>     <li>Vue CLI - for bootstrapping the development of a new Vue app if needed</li> </ul> <p>The module dependencies for the application are not included in the repository due to size requirements and should be installed in the local build/development environment by changing into the ui directory, and executing the npm install command.</p>  <p>For interactive development and previewing of updates, the npm run serve command can be run from the ui directory. Saved changes to the application source code will be reflected in the locally running instance of the application interface at localhost:8080 in a web browser.</p>  <p>Following successful installation of the application dependencies the production code for the application can be generated by changing into the ui directory and executing the npm run build command.</p>  <p>The three provided shell scripts:</p>  <p><code>rebuild-restart-devel.sh</code>, <code>rebuild-restart-testing.sh</code>, and <code>rebuild-restart-production.sh</code> automate the process of checking out the appropriate repository branch, stopping (if running) the corresponding apache web server (devel, testing, or production), removing and rebuilding the corresponding Docker image, and restarting the corresponding Docker container. When these commands are executed the running containers and associated user interface can be accessed at:</p> <ul>     <li>devel - localhost:8082</li>     <li>testing - localhost:8081</li>     <li>production - localhost:80</li> </ul>",
#     "prereserve_doi": {
#       "doi": "10.5072/zenodo.1096462",
#       "recid": 1096462
#     },
#     "publication_date": "2022-08-25",
#     "title": "User interface code for the Data Management Training Clearinghouse",
#     "upload_type": "software",
#     "version": "0.1.0-2022-07ESIPDemo"
#   },
#   "modified": "2022-08-25T20:31:53.041913+00:00",
#   "owner": 10428,
#   "record_id": 1096462,
#   "state": "unsubmitted",
#   "submitted": false,
#   "title": "User interface code for the Data Management Training Clearinghouse"
# }
